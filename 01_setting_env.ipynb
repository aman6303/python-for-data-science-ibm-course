# %%
# setting up the environment git and repo

# %%
# checking up the installed libraries

# !pip list
# Out:
# Package                                     Version
# ------------------------------------------- --------------
# absl-py                                     2.3.1
# accelerate                                  1.8.1
# adagio                                      0.2.6
# aioboto3                                    14.1.0
# aiobotocore                                 2.21.1
# aiofiles                                    24.1.0
# aiohappyeyeballs                            2.6.1
# aiohttp                                     3.12.13
# aiohttp-cors                                0.7.0
# aioitertools                                0.12.0
# aiosignal                                   1.4.0
# aiosqlite                                   0.19.0
# alembic                                     1.16.2
# altair                                      5.5.0
# amazon-q-developer-jupyterlab-ext           3.4.8
# amazon_sagemaker_jupyter_ai_q_developer     1.2.7
# ...

# %%
# testing the env

print("hello world")
# Out:
# hello world
